# %% [markdown]
# # NetCDF Data Catalogue and Available Options
# This notebook scans the NetCDF data directory, extracts the information contained in each directory level, creates a catalogue of the available files, and displays the unique options available for each parameter.

# %% [markdown]
# ### Libraries required to run the script:

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ### Variables:

# %%
# Substitute the string with your data directory
data_directory = Path("../I4C_CPRCM_DATA")

# Define one column for each directory level
columns = ["domain", "running_centre", "reanalysis", "simulation_type", "run_type1",
           "model", "run_type2", "time_interval", "variable", "data_version"]

# Store the information extracted from each file
records = []

# %% [markdown]
# ### NetCDF File Catalogue Creation
#
# This section recursively searches for NetCDF files, extracts the information from each directory level, and stores it together with the file name. Only files matching the expected directory structure are included in the catalogue, which is then converted into a pandas DataFrame.

# %%
# Search for all NetCDF files and extract the directory information
for file in data_directory.rglob("*.nc"):#
    relative_parts = file.relative_to(data_directory).parts

    # There must be one folder per column plus the file name
    if len(relative_parts) == len(columns) + 1:
        record = dict(zip(columns, relative_parts[:-1]))# Pair each column with its corresponding value in the path
        record["file"] = file.name # Store the file name in the 'file' column
        records.append(record)#Store the information for each file as an item in a list

# Create the catalogue
catalogue = pd.DataFrame(records)#Convert the records list of dictionaries into a pandas DataFrame
catalogue
# Out:
#         domain running_centre  reanalysis simulation_type run_type1  \
# 0      EUR-12f      BCCR-UCAN        ERA5      evaluation  r1i1p1f1
# 1      EUR-12f      BCCR-UCAN        ERA5      evaluation  r1i1p1f1
# 2      EUR-12f      BCCR-UCAN        ERA5      evaluation  r1i1p1f1
# 3      EUR-12f      BCCR-UCAN        ERA5      evaluation  r1i1p1f1
# 4      EUR-12f      BCCR-UCAN        ERA5      evaluation  r1i1p1f1
# ...        ...            ...         ...             ...       ...
# 55465  ALPX-3f      BCCR-UCAN  NorESM2-MM          ssp370  r1i1p1f1
# 55466  ALPX-3f      BCCR-UCAN  NorESM2-MM          ssp370  r1i1p1f1
# 55467  ALPX-3f      BCCR-UCAN  NorESM2-MM          ssp370  r1i1p1f1
# 55468  ALPX-3f      BCCR-UCAN  NorESM2-MM          ssp370  r1i1p1f1
# 55469  ALPX-3f      BCCR-UCAN  NorESM2-MM          ssp370  r1i1p1f1
#
#               model run_type2 time_interval variable data_version  \
# 0      WRF451R-CI4C     v1-r1           6hr   zg1000    v20240710
# 1      WRF451R-CI4C     v1-r1           6hr   zg1000    v20240710
# 2      WRF451R-CI4C     v1-r1           6hr   zg1000    v20240710
# 3      WRF451R-CI4C     v1-r1           6hr   zg1000    v20240710
# 4      WRF451R-CI4C     v1-r1           6hr   zg1000    v20240710
# ...             ...       ...           ...      ...          ...
# 55465  WRF451R-CI4C     v1-r1           1hr   hus50m    v20240710
# 55466  WRF451R-CI4C     v1-r1           1hr   hus50m    v20240710
# 55467  WRF451R-CI4C     v1-r1           1hr   hus50m    v20240710
# 55468  WRF451R-CI4C     v1-r1           1hr   hus50m    v20240710
# 55469  WRF451R-CI4C     v1-r1           1hr   hus50m    v20240710
#
#                                                     file
# 0      zg1000_EUR-12f_ERA5_evaluation_r1i1p1f1_BCCR-U...
# 1      zg1000_EUR-12f_ERA5_evaluation_r1i1p1f1_BCCR-U...
# 2      zg1000_EUR-12f_ERA5_evaluation_r1i1p1f1_BCCR-U...
# 3      zg1000_EUR-12f_ERA5_evaluation_r1i1p1f1_BCCR-U...
# 4      zg1000_EUR-12f_ERA5_evaluation_r1i1p1f1_BCCR-U...
# ...                                                  ...
# 55465  hus50m_ALPX-3f_NorESM2-MM_ssp370_r1i1p1f1_BCCR...
# 55466  hus50m_ALPX-3f_NorESM2-MM_ssp370_r1i1p1f1_BCCR...
# 55467  hus50m_ALPX-3f_NorESM2-MM_ssp370_r1i1p1f1_BCCR...
# 55468  hus50m_ALPX-3f_NorESM2-MM_ssp370_r1i1p1f1_BCCR...
# 55469  hus50m_ALPX-3f_NorESM2-MM_ssp370_r1i1p1f1_BCCR...
#
# [55470 rows x 11 columns]

# %% [markdown]
# ### Available Options Extraction
#
# This section extracts the unique values available for each catalogue parameter, removes missing values, and stores the results as alphabetically sorted lists. The available options are then displayed as comma-separated strings for easier consultation.

# %%
# Store the unique available options as sorted lists
available_options = {column: sorted(catalogue[column].dropna().unique().tolist()) for column in columns}

# Display the 
for column, options in available_options.items():
    print(f"{column}: {', '.join(options)}")
# Out:
# domain: ALPX-3f, EUR-12f
# running_centre: BCCR-UCAN
# reanalysis: ERA5, NorESM2-MM
# simulation_type: evaluation, historical, ssp370
# run_type1: r1i1p1f1
# model: WRF451R-CI4C
# run_type2: v1-r1
# time_interval: 1hr, 6hr, day, fx
# variable: cape, cin, clgvi, clhvi, clivi, clt, clwvi, evspsbl, hfls, hfso, hfss, hurs, hus1000, hus200, hus500, hus50m, hus700, hus850, hus925, huss, husscan, mrro, mrros, mrso, mrsofc, mrsol, od550aer, orog, pr, prc, prw, ps, psl, rlds, rlus, rsds, rsus, sfcWind, sfcWindcan, sfcWindmax, sftlaf, sftlf, sfturf, siconca, snc, snd, snw, ta1000, ta200, ta500, ta50m, ta700, ta850, ta925, tas, tascan, tasmax, tasmin, tauu, tauv, ts, tsgree, tsl, tspav, tsroof, tsskin, ua1000, ua100m, ua200, ua500, ua50m, ua700, ua850, ua925, uas, va1000, va100m, va200, va500, va50m, va700, va850, va925, vas, wa1000, wa200, wa500, wa700, wa850, wa925, z0, zg1000, zg200, zg500, zg700, zg850, zg925, zmla
# data_version: v20240710
